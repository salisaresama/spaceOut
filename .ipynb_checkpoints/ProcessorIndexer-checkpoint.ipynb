# %%
# !pip install elasticsearch pandas numpy spacy tqdm
# Out:
# Collecting elasticsearch
#   Downloading elasticsearch-7.6.0-py2.py3-none-any.whl (88 kB)
#      |████████████████████████████████| 88 kB 1.7 MB/s eta 0:00:011
# Collecting pandas
#   Downloading pandas-1.0.3-cp37-cp37m-manylinux1_x86_64.whl (10.0 MB)
#      |████████████████████████████████| 10.0 MB 3.1 MB/s eta 0:00:01
# Collecting numpy
#   Downloading numpy-1.18.2-cp37-cp37m-manylinux1_x86_64.whl (20.2 MB)
#      |████████████████████████████████| 20.2 MB 30.2 MB/s eta 0:00:01B/s eta 0:00:01   | 10.4 MB 30.2 MB/s eta 0:00:01       | 13.6 MB 30.2 MB/s eta 0:00:01��████████████████████████▍      | 16.0 MB 30.2 MB/s eta 0:00:01    |█████████████████████████████▊  | 18.7 MB 30.2 MB/s eta 0:00:01
# Collecting spacy
#   Downloading spacy-2.2.4-cp37-cp37m-manylinux1_x86_64.whl (10.6 MB)
#      |████████████████████████████████| 10.6 MB 21.2 MB/s eta 0:00:01:010:01 MB 21.2 MB/s eta 0:00:01
# Collecting tqdm
#   Downloading tqdm-4.45.0-py2.py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 9.3 MB/s  eta 0:00:01
# Collecting urllib3>=1.21.1
#   Downloading urllib3-1.25.8-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 39.6 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.6.1 in /home/copyfile/anaconda3/envs/gimme/lib/python3.7/site-packages (from pandas) (2.8.1)
# Collecting pytz>=2017.2
#   Downloading pytz-2019.3-py2.py3-none-any.whl (509 kB)
#      |████████████████████████████████| 509 kB 30.2 MB/s eta 0:00:01
# Requirement already satisfied: setuptools in /home/copyfile/anaconda3/envs/gimme/lib/python3.7/site-packages (from spacy) (46.1.3.post20200330)
# Collecting requests<3.0.0,>=2.13.0
#   Downloading requests-2.23.0-py2.py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 6.0 MB/s  eta 0:00:01
# Collecting blis<0.5.0,>=0.4.0
#   Downloading blis-0.4.1-cp37-cp37m-manylinux1_x86_64.whl (3.7 MB)
#      |████████████████████████████████| 3.7 MB 24.9 MB/s eta 0:00:01�███                          | 696 kB 24.9 MB/s eta 0:00:01█████████████████████▋  | 3.4 MB 24.9 MB/s eta 0:00:01
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.3-cp37-cp37m-manylinux1_x86_64.whl (32 kB)
# Collecting thinc==7.4.0
#   Downloading thinc-7.4.0-cp37-cp37m-manylinux1_x86_64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 35.1 MB/s eta 0:00:01
# Collecting plac<1.2.0,>=0.9.6
#   Downloading plac-1.1.3-py2.py3-none-any.whl (20 kB)
# Collecting wasabi<1.1.0,>=0.4.0
#   Downloading wasabi-0.6.0-py3-none-any.whl (20 kB)
# Collecting catalogue<1.1.0,>=0.0.7
#   Downloading catalogue-1.0.0-py2.py3-none-any.whl (7.7 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.2-cp37-cp37m-manylinux1_x86_64.whl (118 kB)
#      |████████████████████████████████| 118 kB 38.9 MB/s eta 0:00:01
# Collecting srsly<1.1.0,>=1.0.2
#   Downloading srsly-1.0.2-cp37-cp37m-manylinux1_x86_64.whl (185 kB)
#      |████████████████████████████████| 185 kB 38.1 MB/s eta 0:00:01
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.2-cp37-cp37m-manylinux1_x86_64.whl (19 kB)
# Requirement already satisfied: six>=1.5 in /home/copyfile/anaconda3/envs/gimme/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas) (1.14.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/copyfile/anaconda3/envs/gimme/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2019.11.28)
# Collecting idna<3,>=2.5
#   Downloading idna-2.9-py2.py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 6.9 MB/s  eta 0:00:01
# Collecting chardet<4,>=3.0.2
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 38.5 MB/s eta 0:00:01
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /home/copyfile/anaconda3/envs/gimme/lib/python3.7/site-packages (from catalogue<1.1.0,>=0.0.7->spacy) (1.6.0)
# Requirement already satisfied: zipp>=0.5 in /home/copyfile/anaconda3/envs/gimme/lib/python3.7/site-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy) (3.1.0)
# Installing collected packages: urllib3, elasticsearch, pytz, numpy, pandas, idna, chardet, requests, blis, cymem, murmurhash, preshed, tqdm, srsly, plac, wasabi, catalogue, thinc, spacy
# Successfully installed blis-0.4.1 catalogue-1.0.0 chardet-3.0.4 cymem-2.0.3 elasticsearch-7.6.0 idna-2.9 murmurhash-1.0.2 numpy-1.18.2 pandas-1.0.3 plac-1.1.3 preshed-3.0.2 pytz-2019.3 requests-2.23.0 spacy-2.2.4 srsly-1.0.2 thinc-7.4.0 tqdm-4.45.0 urllib3-1.25.8 wasabi-0.6.0

# %%
from elasticsearch import Elasticsearch
import pandas as pd
import os
from elasticsearch import helpers
import numpy as np
from datetime import datetime
import collections
import spacy
from spacy_langdetect import LanguageDetector
import time
from tqdm.notebook import tqdm
from multiprocessing import Process, Queue, Manager
from multiprocessing.pool import Pool
from functools import partial
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-86e0db30c683> in <module>
# ----> 1 from elasticsearch import Elasticsearch
#       2 import pandas as pd
#       3 import os
#       4 from elasticsearch import helpers
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'elasticsearch'

# %%
def doc_generator(df, index_name):
    # This function creates documents from dataframe rows, and then 
    # indexes those documents in ElasticSearch
    df_iter = df.iterrows()
    for index, document in df_iter:
        yield {
                "_index": index_name,
                "article": document.to_dict(),
            }
    return True
    
def safe_date(date_value):
    # This method fixes dates so that they don't break ES indexing
    try:
        return (
            pd.to_datetime(date_value) if not pd.isna(date_value)
                else  datetime(1970,1,1,0,0)
        )
    except:
        return (datetime(2000,1,1,0,0))

def clean_and_enrich(df, nlp):
    # This method does basic pre-processing of the text to make it 
    # ready for indexing to ES.

    for i in df.columns:
        if i in ["filename","image_url","localpath","title_page","title_rss", "date_modify", "Unnamed: 0"]:
            df.drop(columns=[i], inplace=True)
             
        

    # Fill empty text with description, else with title, else drop
    df['maintext'].fillna(df['description'], inplace=True)
    df['maintext'].fillna(df['title'], inplace=True)
    df.dropna(subset=["maintext"], inplace=True)

    # Fix date columns. Convert columns to datetime, 
    # fill NaTs with date_download (Empty dates can break ES indexing)
    date_cols = ["date_publish","date_download"]
    for col in date_cols:
        dates = df[col].to_list()
        dates_fixed = [str(i).replace("{'$date': '","").replace("'}","") if isinstance(i, str) else i for i in dates]
        df.loc[:,f"{col}_fixed"] = dates_fixed

    df['date_download'] = df['date_download_fixed']
    df['date_publish'] = df['date_publish_fixed']
    df.drop(columns=[str(i)+"_fixed" for i in date_cols], inplace=True)


    df['date_publish'].fillna(df['date_publish'].apply(safe_date), inplace=True)
    df['date_publish'] = df['date_publish'].apply(safe_date)
    df['date_download'] = df['date_download'].apply(safe_date)
    
    df.fillna("",inplace=True)

    # Drop duplicates by text
    df.drop_duplicates(subset="maintext", inplace=True)

    # Simple wash of text 
    df.replace('\n',' ', regex=True, inplace=True)
    
    docs = list(nlp.pipe(df["maintext"].astype(str)))
    people = [[ent.text.strip('\'s').strip('’') for ent in doc.ents if (ent.label_ == "PERSON")] if doc._.language["language"] == "en" else [] for doc in docs]
    places = [[ent.text for ent in doc.ents if (ent.label_ == "LOC" or ent.label_ == "FAC" or ent.label_ == "GPE")] if doc._.language["language"] == "en" else []  for doc in docs]
    orgs =   [[ent.text for ent in doc.ents if (ent.label_ == "ORG")]  if doc._.language["language"] == "en" else [] for doc in docs]
    concepts = [[ent.text for ent in doc.ents if ent.label_ not in ["LOC","ORG","FACE","PERSON","GPE","PERCENT","ORDINAL","CARDINAL"]] if doc._.language["language"] == "en" else [] for doc in docs]
    languages = [doc._.language["language"] for doc in docs]
    lemmas = [[token.lemma_ for token in doc] for doc in docs]
    
    df["language"] = languages
    df["people"]= people
    df["places"] = places
    df["orgs"] = orgs
    df["concepts"] = concepts
    df["lemma"] = lemmas
            
    return(df)

def scan_for_files(directories):
    filesDone = [f for f in os.listdir(directories[0])]
    filesToProcess = [directories[1] + f for f in os.listdir(directories[1]) if f in filesDone]
    return filesToProcess

def cleanup(filesToDelete, directories):
    for directory in directories: 
        files = os.listdir(directory)
        for i in filesToDelete:
            if i in files:
                os.remove(directory + i)            
                
def index_to_es(df,index_name):
    es = Elasticsearch()
    helpers.bulk(es, doc_generator(df, index_name))

# %%
def main(interval=60):
    
    nlp = spacy.load("en_core_web_lg")
    nlp.max_length = 200000
    nlp.add_pipe(LanguageDetector(), name='language_detector', last=True)
    directories = ["/tempDisk/warc_extract/ready_to_copy/", "/tempDisk/warc_extract/"]
    
    while True:
        # Get files to process
        filesToProcess = scan_for_files(directories)

        # Load them and proces one at a time
        for file in tqdm(filesToProcess):
            df = pd.read_csv(file, engine="python")
            df = clean_and_enrich(df=df, nlp=nlp)
            df.head()
            
            # Index into Elasticsearch
            index_to_es(df, index_name="november2019")
        
        # Delete files
        cleanup(filesToProcess, directories)
        
        # Wait a minute!
        time.sleep(interval)

# %%
if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-263240bbee7e> in <module>
# ----> 1 main()
#
# <ipython-input-3-24cab66d53d0> in main(interval)
#       8     while True:
#       9         # Get files to process
# ---> 10         filesToProcess = scan_for_files(directories)
#      11
#      12         # Load them and proces one at a time
#
# <ipython-input-2-aea8cd06a5bd> in scan_for_files(directories)
#      79 def scan_for_files(directories):
#      80     filesDone = [f for f in os.listdir(directories[0])]
# ---> 81     filesToProcess = [directories[1] + f for f in os.listdir(directories[1]) if f in filesDone]
#      82     return filesToProcess
#      83
#
# KeyboardInterrupt:
